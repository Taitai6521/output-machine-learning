# %% [markdown]
# # そもそも、データ間違ってるから、ひどい

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_title = pd.read_csv('movies.csv')

# %%
df_title
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df_title.rename(columns={'movieId', 'item_id'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-68ac1b99309a> in <module>
# ----> 1 df_title.rename(columns={'movieId', 'item_id'})
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     307         @wraps(func)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#     311         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    4294         4  3  6
#    4295         """
# -> 4296         return super().rename(
#    4297             mapper=mapper,
#    4298             index=index,
#
# ...

# %%
df_title[['title']][:4]
# Out:
#                       title
# 0          Toy Story (1995)
# 1            Jumanji (1995)
# 2   Grumpier Old Men (1995)
# 3  Waiting to Exhale (1995)

# %%
df_title.query('movieId > 100')
# Out:
#        movieId                                  title  \
# 99         101                   Bottle Rocket (1996)
# 100        102                       Mr. Wrong (1996)
# 101        103                   Unforgettable (1996)
# 102        104                   Happy Gilmore (1996)
# 103        105  Bridges of Madison County, The (1995)
# ...        ...                                    ...
# 62418   209157                              We (2018)
# 62419   209159              Window of the Soul (2001)
# 62420   209163                       Bad Poems (2018)
# 62421   209169                    A Girl Thing (2001)
# 62422   209171         Women of Devil's Island (1962)
#
#                                genres
# 99     Adventure|Comedy|Crime|Romance
# 100                            Comedy
# 101           Mystery|Sci-Fi|Thriller
# 102                            Comedy
# 103                     Drama|Romance
# ...                               ...
# 62418                           Drama
# ...

# %%
df_title[df_title['movieId'].isin(([200]))]
# Out:
#      movieId                       title    genres
# 198      200  Tie That Binds, The (1995)  Thriller

# %%
df_title[df_title['title'].str.contains('We (2018)')]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# Empty DataFrame
# Columns: [movieId, title, genres]
# Index: []

# %%
d=pd.Series([2,4])

# %%
d
# Out:
# 0    2
# 1    4
# dtype: int64

# %%
d01 = np.arange(2,4)

# %%
d01
# Out:
# array([2, 3])

# %%
d02 = pd.Series(d01)

# %%
d02
# Out:
# 0    2
# 1    3
# dtype: int64

# %%
p = np.array([2,4])

# %%
p
# Out:
# array([2, 4])

# %%
p1= np.arange(1,20,4)

# %%
p1
# Out:
# array([ 1,  5,  9, 13, 17])

# %%
d01
# Out:
# array([2, 3])

# %%
df_title.index
# Out:
# RangeIndex(start=0, stop=62423, step=1)

# %%
df_title.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
df_title.values
# Out:
# array([[1, 'Toy Story (1995)',
#         'Adventure|Animation|Children|Comedy|Fantasy'],
#        [2, 'Jumanji (1995)', 'Adventure|Children|Fantasy'],
#        [3, 'Grumpier Old Men (1995)', 'Comedy|Romance'],
#        ...,
#        [209163, 'Bad Poems (2018)', 'Comedy|Drama'],
#        [209169, 'A Girl Thing (2001)', '(no genres listed)'],
#        [209171, "Women of Devil's Island (1962)",
#         'Action|Adventure|Drama']], dtype=object)

# %%
df_rating = pd.read_csv('u.data', sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp', 'title'])

# %%
df_rating
# Out:
#        user_id  item_id  rating  timestamp  title
# 0          196      242       3  881250949    NaN
# 1          186      302       3  891717742    NaN
# 2           22      377       1  878887116    NaN
# 3          244       51       2  880606923    NaN
# 4          166      346       1  886397596    NaN
# ...        ...      ...     ...        ...    ...
# 99995      880      476       3  880175444    NaN
# 99996      716      204       5  879795543    NaN
# 99997      276     1090       1  874795795    NaN
# 99998       13      225       2  882399156    NaN
# 99999       12      203       3  879959583    NaN
#
# [100000 rows x 5 columns]

# %%
df_rating.drop(['timestamp'], axis=1,inplace=True)

# %%
df_rating.rename({'item_id', 'movieId'},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-0e2413a9c56c> in <module>
# ----> 1 df_rating.rename({'item_id', 'movieId'},inplace=True)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     307         @wraps(func)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#     311         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    4294         4  3  6
#    4295         """
# -> 4296         return super().rename(
#    4297             mapper=mapper,
#    4298             index=index,
#
# ...

# %%
df_rating.describe()
# Out:
#             user_id        item_id         rating
# count  100000.00000  100000.000000  100000.000000
# mean      462.48475     425.530130       3.529860
# std       266.61442     330.798356       1.125674
# min         1.00000       1.000000       1.000000
# 25%       254.00000     175.000000       3.000000
# 50%       447.00000     322.000000       4.000000
# 75%       682.00000     631.000000       4.000000
# max       943.00000    1682.000000       5.000000

# %%
df_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  100000 non-null  int64
#  1   item_id  100000 non-null  int64
#  2   rating   100000 non-null  int64
# dtypes: int64(3)
# memory usage: 2.3 MB

# %%
df_rating = pd.merge(df_rating, df_title, on='item_id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-6d00fd628ce2> in <module>
# ----> 1 df_rating = pd.merge(df_rating, df_title, on='item_id')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
# ...

# %%
df_title
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df_rating
# Out:
#        user_id  item_id  rating  timestamp  title
# 0          196      242       3  881250949    NaN
# 1          186      302       3  891717742    NaN
# 2           22      377       1  878887116    NaN
# 3          244       51       2  880606923    NaN
# 4          166      346       1  886397596    NaN
# ...        ...      ...     ...        ...    ...
# 99995      880      476       3  880175444    NaN
# 99996      716      204       5  879795543    NaN
# 99997      276     1090       1  874795795    NaN
# 99998       13      225       2  882399156    NaN
# 99999       12      203       3  879959583    NaN
#
# [100000 rows x 5 columns]

# %%
df_rating.groupby('rating')['timestamp'].describe()
# Out:
#           count          mean           std          min           25%  \
# rating
# 1        6110.0  8.836804e+08  5.119870e+06  874729935.0  8.794342e+08
# 2       11370.0  8.837664e+08  5.307663e+06  874728168.0  8.794650e+08
# 3       27145.0  8.835474e+08  5.333161e+06  874724905.0  8.794553e+08
# 4       34174.0  8.833652e+08  5.327826e+06  874724710.0  8.794427e+08
# 5       21201.0  8.835978e+08  5.457200e+06  874725485.0  8.794551e+08
#
#                 50%           75%          max
# rating
# 1       883799947.5  8.880693e+08  893286511.0
# 2       883599971.0  8.885163e+08  893286511.0
# 3       882903645.0  8.882675e+08  893286638.0
# 4       882535666.0  8.880667e+08  893286638.0
# 5       882607356.0  8.886321e+08  893286637.0

# %%
df_rating.groupby('user_id')[['rating']].max()
# Out:
#          rating
# user_id
# 1             5
# 2             5
# 3             5
# 4             5
# 5             5
# ...         ...
# 939           5
# 940           5
# 941           5
# 942           5
# 943           5
#
# [943 rows x 1 columns]

# %%
df_mean =df_rating.groupby('user_id')['rating'].describe()[['mean']]

# %%
df_count = df_rating.groupby('user_id')['rating'].describe()[['count']]

# %%
df_co_me= pd.concat([df_mean, df_count], axis=1)

# %%
df_co_me
# Out:
#              mean  count
# user_id
# 1        3.610294  272.0
# 2        3.709677   62.0
# 3        2.796296   54.0
# 4        4.333333   24.0
# 5        2.874286  175.0
# ...           ...    ...
# 939      4.265306   49.0
# 940      3.457944  107.0
# 941      4.045455   22.0
# 942      4.265823   79.0
# 943      3.410714  168.0
#
# [943 rows x 2 columns]

# %%
df_co_me= pd.concat([df_mean, df_count], axis=0)

# %%
df_co_me
# Out:
#              mean  count
# user_id
# 1        3.610294    NaN
# 2        3.709677    NaN
# 3        2.796296    NaN
# 4        4.333333    NaN
# 5        2.874286    NaN
# ...           ...    ...
# 939           NaN   49.0
# 940           NaN  107.0
# 941           NaN   22.0
# 942           NaN   79.0
# 943           NaN  168.0
#
# [1886 rows x 2 columns]

# %%
df_ra_ti = pd.concat([df_rating, df_title], axis=1)

# %%
df_ra_ti
# Out:
#        user_id  item_id  rating  timestamp title  movieId  \
# 0          196      242       3  881250949   NaN      1.0
# 1          186      302       3  891717742   NaN      2.0
# 2           22      377       1  878887116   NaN      3.0
# 3          244       51       2  880606923   NaN      4.0
# 4          166      346       1  886397596   NaN      5.0
# ...        ...      ...     ...        ...   ...      ...
# 99995      880      476       3  880175444   NaN      NaN
# 99996      716      204       5  879795543   NaN      NaN
# 99997      276     1090       1  874795795   NaN      NaN
# 99998       13      225       2  882399156   NaN      NaN
# 99999       12      203       3  879959583   NaN      NaN
#
#                                     title  \
# 0                        Toy Story (1995)
# 1                          Jumanji (1995)
# 2                 Grumpier Old Men (1995)
# 3                Waiting to Exhale (1995)
# 4      Father of the Bride Part II (1995)
# ...

# %%
df_ra_ti = df_ra_ti.drop(['user_id', 'item_id', 'title', 'genres'], axis=1)

# %%
df_ra_ti
# Out:
#        rating  timestamp  movieId
# 0           3  881250949      1.0
# 1           3  891717742      2.0
# 2           1  878887116      3.0
# 3           2  880606923      4.0
# 4           1  886397596      5.0
# ...       ...        ...      ...
# 99995       3  880175444      NaN
# 99996       5  879795543      NaN
# 99997       1  874795795      NaN
# 99998       2  882399156      NaN
# 99999       3  879959583      NaN
#
# [100000 rows x 3 columns]

# %%
df_ra_ti.reset_index()
# Out:
#        index  rating  timestamp  movieId
# 0          0       3  881250949      1.0
# 1          1       3  891717742      2.0
# 2          2       1  878887116      3.0
# 3          3       2  880606923      4.0
# 4          4       1  886397596      5.0
# ...      ...     ...        ...      ...
# 99995  99995       3  880175444      NaN
# 99996  99996       5  879795543      NaN
# 99997  99997       1  874795795      NaN
# 99998  99998       2  882399156      NaN
# 99999  99999       3  879959583      NaN
#
# [100000 rows x 4 columns]

# %%
df_ra_ti.plot(bins=10,kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_ra_ti['rating'].plot(bins=100, kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxenplot(data=df_title, x='rating')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-9231bc97b512> in <module>
# ----> 1 sns.boxenplot(data=df_title, x='rating')
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in boxenplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, k_depth, linewidth, scale, outlier_prop, trust_alpha, showfliers, ax, **kwargs)
#    2619 ):
#    2620
# -> 2621     plotter = _LVPlotter(x, y, hue, data, order, hue_order,
#    2622                          orient, color, palette, saturation,
# ...

# %%
import tqdm

# %%
df_title.sort_values(by='movieId', ascending=False).tail()
# Out:
#    movieId                               title  \
# 4        5  Father of the Bride Part II (1995)
# 3        4            Waiting to Exhale (1995)
# 2        3             Grumpier Old Men (1995)
# 1        2                      Jumanji (1995)
# 0        1                    Toy Story (1995)
#
#                                         genres
# 4                                       Comedy
# 3                         Comedy|Drama|Romance
# 2                               Comedy|Romance
# 1                   Adventure|Children|Fantasy
# 0  Adventure|Animation|Children|Comedy|Fantasy

# %%
df = pd.read_csv('u.data', sep='\t',names=['user_id', 'item_id', 'rating', 'timestamp'])

# %%
df
# Out:
#        user_id  item_id  rating  timestamp
# 0          196      242       3  881250949
# 1          186      302       3  891717742
# 2           22      377       1  878887116
# 3          244       51       2  880606923
# 4          166      346       1  886397596
# ...        ...      ...     ...        ...
# 99995      880      476       3  880175444
# 99996      716      204       5  879795543
# 99997      276     1090       1  874795795
# 99998       13      225       2  882399156
# 99999       12      203       3  879959583
#
# [100000 rows x 4 columns]

# %%
df = df.groupby('rating').describe()
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-b3420fd7b1eb> in <module>
# ----> 1 df = df.groupby('rating').describe()
#       2 df
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
df = df.pivot_table('rating','item_id' ,'timestamp')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-c8cf2cd64cc5> in <module>
# ----> 1 df = df.pivot_table('rating','item_id' ,'timestamp')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6820         from pandas.core.reshape.pivot import pivot_table
#    6821
# -> 6822         return pivot_table(
#    6823             self,
#    6824             values=values,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      86         for i in values:
#      87             if i not in data:
# ---> 88                 raise KeyError(i)
#      89
#      90         to_filter = []
#
# KeyError: 'rating'

# %%
df
# Out:
# timestamp  874724710  874724727  874724754  874724781  874724843  874724882  \
# rating
# 1                NaN        NaN        NaN        NaN        NaN        NaN
# 2                NaN        NaN        NaN        NaN        NaN        NaN
# 3                NaN        NaN        NaN        NaN        NaN        NaN
# 4              259.0      259.0      259.0      259.0      259.0      259.0
# 5                NaN        NaN        NaN        NaN        NaN        NaN
#
# timestamp  874724905  874724937  874724988  874725081  ...  893286373  \
# rating                                                 ...
# 1                NaN        NaN        NaN        NaN  ...      729.0
# 2                NaN        NaN        NaN        NaN  ...        NaN
# 3              259.0        NaN        NaN        NaN  ...        NaN
# 4                NaN      259.0      259.0      259.0  ...        NaN
# 5                NaN        NaN        NaN        NaN  ...        NaN
#
# ...
