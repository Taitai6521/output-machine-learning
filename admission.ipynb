# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_ad = pd.read_csv('Admission.csv')

# %%
df_ad
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Admission Chance
# ...

# %%
X = df_ad.iloc[:,2:-1]
y = df_ad.iloc[:,-1]

# %%
X =

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Admission Chance, Length: 400, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y, test_size=0.22, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression(fit_intercept=True)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)

# %%
plt.scatter(y_test,y_pred,color='r')

# %%
k=X_test.shape[1]
n=len(X_test)

# %%
n
# Out:
# 88

# %%
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error
from math import sqrt
RMSE = float(format(np.sqrt(mean_squared_error(y_test,y_pred)),'.3f'))
MSE =mean_squared_error(y_test, y_pred)
MAE =mean_absolute_error(y_test, y_pred)
r2 =r2_score(y_test, y_pred)
adj_r2 = 1 -(1-r2)*(1-n)/(1-k-n)
AMPE = np.mean(np.abs((y_test-y_pred)/y_test))*100

# %%
print(RMSE,MSE,MAE,r2,adj_r2, AMPE)
# Out:
# 0.072 0.005156679526039082 0.051755575198770436 0.7105038810152859 0.7291810499820417 8.373863659631635

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x_surf, y_surf = np.meshgrid(np.linspace(df_ad['TOEFL Score'].min(),df_ad['TOEFL Score'].max(),100),np.linspace(df_ad['GRE Score'].min(), df_ad['GRE Score'].min(),100))

# %%
onlyX = pd.DataFrame({'toefl':x_surf.ravel(), 'gre':y_surf.ravel()})

# %%
onlyX.shape
# Out:
# (10000, 2)

# %%
onlyX
# Out:
#            toefl    gre
# 0      92.000000  290.0
# 1      92.282828  290.0
# 2      92.565657  290.0
# 3      92.848485  290.0
# 4      93.131313  290.0
# ...          ...    ...
# 9995  118.868687  290.0
# 9996  119.151515  290.0
# 9997  119.434343  290.0
# 9998  119.717172  290.0
# 9999  120.000000  290.0
#
# [10000 rows x 2 columns]

# %%
fittedY = reg.predict(onlyX)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-46f74bef8a4e> in <module>
# ----> 1 fittedY = reg.predict(onlyX)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     219
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# --> 221         return safe_sparse_dot(X, self.coef_.T,
#     222                                dense_output=True) + self.intercept_
#     223
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
# ...

# %%
df_ad = df_ad.drop(['Serial No.'],axis=1)

# %%
column_headers = df_ad.columns.values

# %%
column_headers.shape
# Out:
# (8,)

# %%
df_ad
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Admission Chance
# 0                0.92
# 1                0.76
# ...

# %%
i = 1
fig, axes = plt.subplots(2,4,figsize=(20,20))
for column_header in column_headers:
    plt.subplot(2,4,i)
    sns.distplot(df_ad[column_header])
    i += 1
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
i = 1
fig, ax = plt.subplots(2, 4, figsize = (20, 20))

for column_header in column_headers:
    plt.subplot(2,4,i)
    sns.distplot(df_ad[column_header])
    i = i + 1
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_ad.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df_ad)

# %%
sns.boxenplot(data=df_ad)
# Out:
# <AxesSubplot:>

# %%
i = 1
fig, ax = plt.subplots(2, 4, figsize = (20, 20))

for column_header in column_headers:
    plt.subplot(2,4,i)
    sns.boxenplot(df_ad[column_header])
    i = i + 1
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.heatmap(df_ad.isnull(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df_ad
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Admission Chance
# 0                0.92
# 1                0.76
# ...

# %%
df_ad
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Admission Chance
# 0                0.92
# 1                0.76
# ...

# %%
X = df_ad.drop(['Admission Chance', 'University Rating', 'SOP', 'LOR', 'CGPA', 'Research'],axis=1)
y = df_ad['Admission Chance']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-fe566698f442> in <module>
# ----> 1 X = df_ad.drop(['Admission Chance', 'University Rating', 'SOP', 'LOR', 'CGPA', 'Research'],axis=1)
#       2 y = df_ad['Admission Chance']
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
# ...

# %%
X = df_ad[['TOEFL Score','GRE Score']]
y = df_ad['Admission Chance']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression(fit_intercept=True)
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
k=X_test.shape[1]
n=len(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_pred)) , '.3f'))
MSE = mean_squared_error(y_test, y_pred)
MAE = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
MAPE = np.mean( np.abs((y_test - y_pred) /y_test ) ) * 100

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2, '\nMean Absolute Percentage Error =', MAPE, '%')
# Out:
# RMSE = 0.083
# MSE = 0.006816077266875628
# MAE = 0.058929749037738385
# R2 = 0.6248199736307396
# Adjusted R2 = 0.6150750378808887
# Mean Absolute Percentage Error = 9.550561881366844 %

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x_surf, y_surf = np.meshgrid(np.linspace(df_ad['TOEFL Score'].min(), df_ad['TOEFL Score'].max(),100), np.linspace(df_ad['GRE Score'].min(), df_ad['GRE Score'].max(),100))

# %%
onlyX = pd.DataFrame({'gre':x_surf.ravel(), 'toefl': y_surf.ravel()})

# %%
fittedY = reg.predict(onlyX)

# %%
X_test.shape
# Out:
# (80, 2)

# %%
fittedY = fittedY.reshape(x_surf.shape)

# %%
x_surf.shape
# Out:
# (100, 100)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
axes = fig.add_subplot(projection='3d')
axes.scatter(df_ad['TOEFL Score'], df_ad['GRE Score'],df_ad['Admission Chance'],color='red')
axes.plot_surface(x_surf,y_surf,fittedY, color='blue',alpha=0.3)
axes.vi
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-61a8cdb18e09> in <module>
#       4 axes.scatter(df_ad['TOEFL Score'], df_ad['GRE Score'],df_ad['Admission Chance'],color='red')
#       5 axes.plot_surface(x_surf,y_surf,fittedY, color='blue',alpha=0.3)
# ----> 6 axes.vi
#
# AttributeError: 'Axes3DSubplot' object has no attribute 'vi'

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(111)
axes = fig.subplot(projection='3d')

axes.plot_surface(x_surf,y_surf,fittedY)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-129767dca098> in <module>
#       1 from mpl_toolkits.mplot3d import Axes3D
#       2 fig = plt.figure(111)
# ----> 3 axes = fig.subplot(projection='3d')
#       4
#       5 axes.plot_surface(x_surf,y_surf,fittedY)
#
# AttributeError: 'Figure' object has no attribute 'subplot'
