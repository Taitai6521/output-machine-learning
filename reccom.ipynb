# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_title = pd.read_csv('ratings_real.csv')

# %%
df_data = df_title.apply(lambda x: x[:10000])

# %%
df_data[~df_data['userId']!=0].query('movieId>1000')
# Out:
#       userId  movieId  rating   timestamp
# 5          1     1088     4.0  1147868495
# 6          1     1175     3.5  1147868826
# 7          1     1217     3.5  1147878326
# 8          1     1237     5.0  1147868839
# 9          1     1250     4.0  1147868414
# ...      ...      ...     ...         ...
# 9876      72     4148     4.0   982342515
# 9877      72     5060     4.0   980646647
# 9914      73     1061     3.0   857830146
# 9915      73     1073     4.0   857829799
# 9916      73     1356     4.0   857829861
#
# [7634 rows x 4 columns]

# %%
df_data[~df_data['userId']!=0].query('rating<3 and movieId<100')
# Out:
#       userId  movieId  rating   timestamp
# 71         2       62     0.5  1141417130
# 1156       5       39     2.0   858627955
# 1307       8        7     1.0   890492414
# 1715      12        2     2.0   968257492
# 1716      12        3     2.0  1137231033
# 1721      12       20     1.0   964631207
# 1722      12       21     2.0   940768073
# 1725      12       27     2.0   968257706
# 1727      12       31     2.0   940768545
# 1728      12       32     2.0   940767592
# 1731      12       45     2.0   940767647
# 1733      12       48     2.0  1137231133
# 1735      12       54     2.0   940801433
# 1738      12       88     2.5  1137232800
# 2455      13       60     0.5  1237969640
# 3017      18        3     1.5  1108273290
# 3204      19       44     2.0  1454709124
# 3205      19       48     1.5  1450544698
# 3661      20        2     2.5  1062004110
# 3866      23        7     2.0   943135696
# 3868      23       14     2.0   942969035
# ...

# %%
df_data[df_data['userId']].isin([1000])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-2279418555d1> in <module>
# ----> 1 df_data[df_data['userId']].isin([1000])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
df_data = df_data.rename(columns={'userId':'id'}, index={0:'ai'})
df_data
# Out:
#       id  movieId  rating   timestamp
# ai     1      296     5.0  1147880044
# 1      1      306     3.5  1147868817
# 2      1      307     5.0  1147868828
# 3      1      665     5.0  1147878820
# 4      1      899     3.5  1147868510
# ...   ..      ...     ...         ...
# 9995  75      736     4.0  1537207939
# 9996  75      778     3.0  1537208100
# 9997  75      783     3.0  1537348896
# 9998  75      805     3.5  1537348872
# 9999  75      832     3.0  1537208657
#
# [10000 rows x 4 columns]

# %%
df_data01 = df_data[(df_data['id']!=0)&(df_data['rating']!=0)]
df_data01
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5469982d0be2> in <module>
# ----> 1 df_data01 = df_data[(df_data['id']!=0)&(df_data['rating']!=0)]
#       2 df_data01
#
# NameError: name 'df_data' is not defined

# %%
df_title = pd.read_csv('movies.csv')

# %%
df_title
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df_ti_da = pd.merge(df_title, df_data,on='movieId')

# %%
df_ti_da_toy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 0 to 9281
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   movieId    34 non-null     int64
#  1   title      34 non-null     object
#  2   genres     34 non-null     object
#  3   userId     34 non-null     int64
#  4   rating     34 non-null     float64
#  5   timestamp  34 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.9+ KB

# %%
df_ti_da_toy.info
# Out:
#       movieId                    title  \
# 0           1         Toy Story (1995)
# 1           1         Toy Story (1995)
# 2           1         Toy Story (1995)
# 3           1         Toy Story (1995)
# 4           1         Toy Story (1995)
# 5           1         Toy Story (1995)
# 6           1         Toy Story (1995)
# 7           1         Toy Story (1995)
# 8           1         Toy Story (1995)
# 9           1         Toy Story (1995)
# 10          1         Toy Story (1995)
# 11          1         Toy Story (1995)
# 12          1         Toy Story (1995)
# 13          1         Toy Story (1995)
# 14          1         Toy Story (1995)
# 15          1         Toy Story (1995)
# 16          1         Toy Story (1995)
# 17          1         Toy Story (1995)
# 18          1         Toy Story (1995)
# 19          1         Toy Story (1995)
# 20          1         Toy Story (1995)
# 21          1         Toy Story (1995)
# 22          1         Toy Story (1995)
# ...

# %%
df_ti_da_toy= df_ti_da[df_ti_da['title'].str.contains('Toy')]
df_ti_da_toy
# Out:
#       movieId                    title  \
# 0           1         Toy Story (1995)
# 1           1         Toy Story (1995)
# 2           1         Toy Story (1995)
# 3           1         Toy Story (1995)
# 4           1         Toy Story (1995)
# 5           1         Toy Story (1995)
# 6           1         Toy Story (1995)
# 7           1         Toy Story (1995)
# 8           1         Toy Story (1995)
# 9           1         Toy Story (1995)
# 10          1         Toy Story (1995)
# 11          1         Toy Story (1995)
# 12          1         Toy Story (1995)
# 13          1         Toy Story (1995)
# 14          1         Toy Story (1995)
# 15          1         Toy Story (1995)
# 16          1         Toy Story (1995)
# 17          1         Toy Story (1995)
# 18          1         Toy Story (1995)
# 19          1         Toy Story (1995)
# 20          1         Toy Story (1995)
# 21          1         Toy Story (1995)
# 22          1         Toy Story (1995)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 10000
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-e48a92410172> in <module>
# ...

# %%
df_ti_da_mean = df_ti_da.groupby('title')['rating'].describe()[['mean']]

# %%
df_ti_da_count = df_ti_da.groupby('title')['rating'].describe()[['count']]

# %%
df_tida_co_me = pd.concat([df_ti_da_count,df_ti_da_mean], axis=1)

# %%
df_tida_co_me
# Out:
#                                 count   mean
# title
# $5 a Day (2008)                   1.0  4.000
# 'Round Midnight (1986)            1.0  4.000
# 'burbs, The (1989)                2.0  2.500
# (500) Days of Summer (2009)       3.0  3.500
# ...And Justice for All (1979)     1.0  2.500
# ...                               ...    ...
# Zoolander (2001)                  5.0  3.400
# Zootopia (2016)                   2.0  4.000
# xXx (2002)                        2.0  2.000
# xXx: State of the Union (2005)    1.0  0.500
# ¡Three Amigos! (1986)             4.0  2.875
#
# [3287 rows x 2 columns]

# %%
df_tida_co_me.reset_index()
# Out:
#                                title  count   mean
# 0                    $5 a Day (2008)    1.0  4.000
# 1             'Round Midnight (1986)    1.0  4.000
# 2                 'burbs, The (1989)    2.0  2.500
# 3        (500) Days of Summer (2009)    3.0  3.500
# 4      ...And Justice for All (1979)    1.0  2.500
# ...                              ...    ...    ...
# 3282                Zoolander (2001)    5.0  3.400
# 3283                 Zootopia (2016)    2.0  4.000
# 3284                      xXx (2002)    2.0  2.000
# 3285  xXx: State of the Union (2005)    1.0  0.500
# 3286           ¡Three Amigos! (1986)    4.0  2.875
#
# [3287 rows x 3 columns]

# %%
df_tida_co_me['mean'].plot(bins=100, kind='hist', color='r')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_tida_co_me['count'].plot(bins=100, kind='hist', color='r')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_tida_co_me[df_tida_co_me['mean']==5]
# Out:
#                                                     count  mean
# title
# 1984 (1956)                                           1.0   5.0
# 47 Ronin (2013)                                       1.0   5.0
# 5 Centimeters per Second (Byôsoku 5 senchimêtor...    1.0   5.0
# 8 Seconds (1994)                                      1.0   5.0
# Abbott and Costello Meet Frankenstein (1948)          1.0   5.0
# ...                                                   ...   ...
# Withnail & I (1987)                                   1.0   5.0
# World of Apu, The (Apur Sansar) (1959)                1.0   5.0
# Your Friends and Neighbors (1998)                     1.0   5.0
# Z (1969)                                              1.0   5.0
# Zero Effect (1998)                                    1.0   5.0
#
# [132 rows x 2 columns]

# %%
df_tida_co_me.sort_values(by='count', ascending=False).head(100)
# Out:
#                                                     count      mean
# title
# Star Wars: Episode IV - A New Hope (1977)            42.0  4.166667
# Pulp Fiction (1994)                                  37.0  4.324324
# Forrest Gump (1994)                                  37.0  4.175676
# Silence of the Lambs, The (1991)                     37.0  4.189189
# Shawshank Redemption, The (1994)                     36.0  4.347222
# ...                                                   ...       ...
# Léon: The Professional (a.k.a. The Professional...   14.0  4.214286
# Breakfast Club, The (1985)                           14.0  3.857143
# L.A. Confidential (1997)                             14.0  4.107143
# Birdcage, The (1996)                                 14.0  3.857143
# Inception (2010)                                     14.0  4.392857
#
# [100 rows x 2 columns]

# %%
df_tida_co_me.sort_values(by='count', ascending=True).head(100)
# Out:
#                                            count  mean
# title
# $5 a Day (2008)                              1.0   4.0
# Mamma Mia! (2008)                            1.0   4.0
# Maleficent (2014)                            1.0   4.0
# Major Payne (1995)                           1.0   2.0
# Maid to Order (1987)                         1.0   2.0
# ...                                          ...   ...
# xXx: State of the Union (2005)               1.0   0.5
# Kate & Leopold (2001)                        1.0   3.5
# Karate Kid, The (2010)                       1.0   2.0
# Kingdom of Dreams and Madness, The (2013)    1.0   4.0
# Menace II Society (1993)                     1.0   3.0
#
# [100 rows x 2 columns]

# %%
df_ti_da
# Out:
#       movieId                                         title  \
# 0           1                              Toy Story (1995)
# 1           1                              Toy Story (1995)
# 2           1                              Toy Story (1995)
# 3           1                              Toy Story (1995)
# 4           1                              Toy Story (1995)
# ...       ...                                           ...
# 9995   195159      Spider-Man: Into the Spider-Verse (2018)
# 9996   200818      John Wick: Chapter 3 – Parabellum (2019)
# 9997   200838             Pokémon: Detective Pikachu (2019)
# 9998   203375                        Ford v. Ferrari (2019)
# 9999   203519  Fast & Furious Presents: Hobbs & Shaw (2019)
#
#                                            genres  userId  rating   timestamp
# 0     Adventure|Animation|Children|Comedy|Fantasy       2     3.5  1141415820
# 1     Adventure|Animation|Children|Comedy|Fantasy       3     4.0  1439472215
# ...

# %%
userid_movietitle_matrix = df_ti_da.pivot_table(index='userId', columns='title', values='rating')

# %%
userid_movietitle_matrix
# Out:
# title   $5 a Day (2008)  'Round Midnight (1986)  'burbs, The (1989)  \
# userId
# 1                   NaN                     NaN                 NaN
# 2                   NaN                     NaN                 NaN
# 3                   NaN                     NaN                 NaN
# 4                   NaN                     NaN                 NaN
# 5                   NaN                     NaN                 NaN
# ...                 ...                     ...                 ...
# 71                  NaN                     NaN                 NaN
# 72                  NaN                     NaN                 3.0
# 73                  NaN                     NaN                 NaN
# 74                  NaN                     NaN                 NaN
# 75                  NaN                     NaN                 NaN
#
# title   (500) Days of Summer (2009)  ...And Justice for All (1979)  10 (1979)  \
# userId
# ...

# %%
titanic = userid_movietitle_matrix['Titanic (1997)']

# %%
titanic
# Out:
# userId
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
#      ...
# 71    5.0
# 72    5.0
# 73    NaN
# 74    NaN
# 75    NaN
# Name: Titanic (1997), Length: 75, dtype: float64

# %%
starwars = userid_movietitle_matrix['Star Wars: Episode IV - A New Hope (1977)']

# %%
# Out:
# count    42.000000
# mean      4.166667
# std       0.908407
# min       1.000000
# 25%       4.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: Star Wars: Episode IV - A New Hope (1977), dtype: float64

# %%
titanic_correlations = pd.DataFrame(userid_movietitle_matrix.corrwith(titanic), columns=['Correlation'])
# Out:
# /Users/SN/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Users/SN/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
titanic_correlations = titanic_correlations.join(df_tida_co_me['count'])

# %%
titanic_correlations
# Out:
#                                 Correlation  count
# title
# $5 a Day (2008)                         NaN    1.0
# 'Round Midnight (1986)                  NaN    1.0
# 'burbs, The (1989)                      1.0    2.0
# (500) Days of Summer (2009)             NaN    3.0
# ...And Justice for All (1979)           NaN    1.0
# ...                                     ...    ...
# Zoolander (2001)                        NaN    5.0
# Zootopia (2016)                         NaN    2.0
# xXx (2002)                              NaN    2.0
# xXx: State of the Union (2005)          NaN    1.0
# ¡Three Amigos! (1986)                  -1.0    4.0
#
# [3287 rows x 2 columns]

# %%
titanic_correlations.dropna(inplace=True)
titanic_correlations
# Out:
#                                                     Correlation  count
# title
# 'burbs, The (1989)                                     1.000000    2.0
# 10 Things I Hate About You (1999)                      0.866025    4.0
# 101 Dalmatians (1996)                                 -0.277350    4.0
# 101 Dalmatians (One Hundred and One Dalmatians)...     0.277350    5.0
# 12 Angry Men (1957)                                    0.722222    9.0
# ...                                                         ...    ...
# X2: X-Men United (2003)                                0.537856   10.0
# You've Got Mail (1998)                                 0.430331    6.0
# Young Frankenstein (1974)                              0.198030    6.0
# Young Guns (1988)                                     -0.654654    5.0
# ¡Three Amigos! (1986)                                 -1.000000    4.0
#
# [810 rows x 2 columns]

# %%
df_tida_co_me
# Out:
#                                 count   mean
# title
# $5 a Day (2008)                   1.0  4.000
# 'Round Midnight (1986)            1.0  4.000
# 'burbs, The (1989)                2.0  2.500
# (500) Days of Summer (2009)       3.0  3.500
# ...And Justice for All (1979)     1.0  2.500
# ...                               ...    ...
# Zoolander (2001)                  5.0  3.400
# Zootopia (2016)                   2.0  4.000
# xXx (2002)                        2.0  2.000
# xXx: State of the Union (2005)    1.0  0.500
# ¡Three Amigos! (1986)             4.0  2.875
#
# [3287 rows x 2 columns]

# %%
star_corr=pd.DataFrame(userid_movietitle_matrix.corrwith(starwars), columns=['corre_star'])

# %%
star_corr = star_corr.join(df_tida_co_me['count'])
star_corr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-a0afd5844df0> in <module>
# ----> 1 star_corr = star_corr.join(df_tida_co_me['count'])
#       2 star_corr
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         5  K5  A5  NaN
#    7869         """
# -> 7870         return self._join_compat(
#    7871             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7872         )
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7884
#    7885         if isinstance(other, DataFrame):
# -> 7886             return merge(
#    7887                 self,
#    7888                 other,
#
# ...

# %%
pulp = userid_movietitle_matrix['Pulp Fiction (1994)']

# %%
corr_pu = pd.DataFrame(userid_movietitle_matrix.corrwith(pulp), columns=['corr_pulp'])
# Out:
# /Users/SN/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Users/SN/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_pu = corr_pu.join(df_tida_co_me['count'])

# %%
corr_pu
# Out:
#                                 corr_pulp  count
# title
# $5 a Day (2008)                       NaN    1.0
# 'Round Midnight (1986)                NaN    1.0
# 'burbs, The (1989)                1.00000    2.0
# (500) Days of Summer (2009)           NaN    3.0
# ...And Justice for All (1979)         NaN    1.0
# ...                                   ...    ...
# Zoolander (2001)                 -0.57735    5.0
# Zootopia (2016)                   1.00000    2.0
# xXx (2002)                        1.00000    2.0
# xXx: State of the Union (2005)        NaN    1.0
# ¡Three Amigos! (1986)                 NaN    4.0
#
# [3287 rows x 2 columns]

# %%
corr_pu.dropna()
# Out:
#                                                     corr_pulp  count
# title
# 'burbs, The (1989)                                   1.000000    2.0
# 10 Things I Hate About You (1999)                    0.500000    4.0
# 101 Dalmatians (1996)                               -1.000000    4.0
# 101 Dalmatians (One Hundred and One Dalmatians)...   0.000000    5.0
# 12 Angry Men (1957)                                  0.632456    9.0
# ...                                                       ...    ...
# Zack and Miri Make a Porno (2008)                    0.000000    3.0
# Zombieland (2009)                                    1.000000    3.0
# Zoolander (2001)                                    -0.577350    5.0
# Zootopia (2016)                                      1.000000    2.0
# xXx (2002)                                           1.000000    2.0
#
# [1022 rows x 2 columns]

# %%
corr_pu.sort_values('corr_pulp',ascending=False)
# Out:
#                                                corr_pulp  count
# title
# xXx (2002)                                           1.0    2.0
# Apocalypto (2006)                                    1.0    2.0
# Harry Potter and the Half-Blood Prince (2009)        1.0    3.0
# Homeward Bound: The Incredible Journey (1993)        1.0    4.0
# In the Mood For Love (Fa yeung nin wa) (2000)        1.0    2.0
# ...                                                  ...    ...
# Your Friends and Neighbors (1998)                    NaN    1.0
# Z (1969)                                             NaN    1.0
# Zero Effect (1998)                                   NaN    1.0
# xXx: State of the Union (2005)                       NaN    1.0
# ¡Three Amigos! (1986)                                NaN    4.0
#
# [3287 rows x 2 columns]

# %%
corr_pu[corr_pu['count']>10].sort_values('corr_pulp', ascending=False).head()
# Out:
#                           corr_pulp  count
# title
# Pulp Fiction (1994)        1.000000   37.0
# Beautiful Mind, A (2001)   0.870388   12.0
# Iron Man (2008)            0.868243   12.0
# Kill Bill: Vol. 2 (2004)   0.850795   14.0
# Goodfellas (1990)          0.846715   12.0

# %%
userid_movietitle_matrix
# Out:
# title   $5 a Day (2008)  'Round Midnight (1986)  'burbs, The (1989)  \
# userId
# 1                   NaN                     NaN                 NaN
# 2                   NaN                     NaN                 NaN
# 3                   NaN                     NaN                 NaN
# 4                   NaN                     NaN                 NaN
# 5                   NaN                     NaN                 NaN
# ...                 ...                     ...                 ...
# 71                  NaN                     NaN                 NaN
# 72                  NaN                     NaN                 3.0
# 73                  NaN                     NaN                 NaN
# 74                  NaN                     NaN                 NaN
# 75                  NaN                     NaN                 NaN
#
# title   (500) Days of Summer (2009)  ...And Justice for All (1979)  10 (1979)  \
# userId
# ...

# %% [markdown]
# # ここが一番のポイント

# %%
movie_corr = userid_movietitle_matrix.corr(method='pearson', min_periods=8)

# %%
movie_corr
# Out:
# title                           $5 a Day (2008)  'Round Midnight (1986)  \
# title
# $5 a Day (2008)                             NaN                     NaN
# 'Round Midnight (1986)                      NaN                     NaN
# 'burbs, The (1989)                          NaN                     NaN
# (500) Days of Summer (2009)                 NaN                     NaN
# ...And Justice for All (1979)               NaN                     NaN
# ...                                         ...                     ...
# Zoolander (2001)                            NaN                     NaN
# Zootopia (2016)                             NaN                     NaN
# xXx (2002)                                  NaN                     NaN
# xXx: State of the Union (2005)              NaN                     NaN
# ¡Three Amigos! (1986)                       NaN                     NaN
#
# title                           'burbs, The (1989)  \
# title
# ...

# %%
df_my = pd.read_csv('My_Ratings_01.csv')
df_my
# Out:
#                                   Movie Name  Ratings
# 0                           Liar Liar (1997)        5
# 1  Star Wars: Episode IV - A New Hope (1977)        1

# %%
df_my['Movie Name'][0]
# Out:
# 'Liar Liar (1997)'

# %%
similar_movies_list = pd.Series()

for i in range(0,2):
    similar_movie=movie_corr[df_my['Movie Name'][i]].dropna()
    similar_movie=similar_movie.apply(lambda x: x*df_my['Ratings'][i])
    similar_movies_list = similar_movies_list.append(similar_movie)
# Out:
# <ipython-input-94-6f8c37eef5d0>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   similar_movies_list = pd.Series()

# %%
similar_movies_list.sort_values(inplace=True, ascending=False)

# %%
similar_movies_list
# Out:
# Liar Liar (1997)                              5.000000
# Jerry Maguire (1996)                          3.675833
# Lion King, The (1994)                         3.443141
# Forrest Gump (1994)                           2.651999
# Men in Black (a.k.a. MIB) (1997)              2.605941
#                                                 ...
# Face/Off (1997)                              -0.394645
# Mission: Impossible (1996)                   -0.512143
# Willy Wonka & the Chocolate Factory (1971)   -0.602667
# Jumanji (1995)                               -0.616123
# Shawshank Redemption, The (1994)             -2.749860
# Length: 221, dtype: float64

# %%
similar_movies_list.head(10)
# Out:
# Liar Liar (1997)                       5.000000
# Jerry Maguire (1996)                   3.675833
# Lion King, The (1994)                  3.443141
# Forrest Gump (1994)                    2.651999
# Men in Black (a.k.a. MIB) (1997)       2.605941
# Dead Poets Society (1989)              2.323123
# There's Something About Mary (1998)    2.093148
# Contact (1997)                         2.051957
# Aladdin (1992)                         1.404879
# Silence of the Lambs, The (1991)       1.047428
# dtype: float64

# %%
df_ti_da[df_ti_da['title'].str.contains('Star Wars: Episode IV - A New Hope (1977)')]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# Empty DataFrame
# Columns: [movieId, title, genres, userId, rating, timestamp]
# Index: []

# %%
df_corr = userid_movietitle_matrix.corr(method='pearson', min_periods=10)

# %%
movie_list_similar = pd.Series()

for i in range(0,2):
    movie_similar = userid_movietitle_matrix[df_my['Movie Name'][i]].dropna()
    movie_similar = movie_similar.apply(lambda x: x*df_my['Ratings'][i])
    movie_list_simisar = movie_list_similar.append(movie_similar)
# Out:
# <ipython-input-109-681e48768809>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   movie_list_similar = pd.Series()

# %%
movie_list_simisar.sort_values(inplace=True, ascending=False)
movie_list_simisar
# Out:
# 36    5.0
# 40    5.0
# 5     5.0
# 6     5.0
# 10    5.0
# 12    5.0
# 20    5.0
# 23    5.0
# 28    5.0
# 73    5.0
# 2     5.0
# 72    5.0
# 71    5.0
# 61    5.0
# 69    5.0
# 64    5.0
# 44    4.5
# 43    4.5
# 38    4.5
# 13    4.5
# 57    4.0
# 67    4.0
# 3     4.0
# 9     4.0
# 70    4.0
# 68    4.0
# 21    4.0
# 75    4.0
# 56    4.0
# 59    4.0
# 41    4.0
# 47    4.0
# 19    3.5
# 39    3.5
# 4     3.5
# 51    3.5
# 26    3.0
# 18    3.0
# 8     3.0
# 25    3.0
# 27    2.0
# 31    1.0
# dtype: float64
