# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_ice = pd.read_csv('IceCreamData.csv')

# %%
df_ice
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
sns.jointplot(x='Temperature',y='Revenue' ,data=df_ice, color='r',)

# %%
sns.pairplot(data=df_ice)

# %%
sns.lmplot(x='Temperature',y='Revenue',data=df_ice)

# %%
sns.rugplot(data=df_ice)
# Out:
# <AxesSubplot:>

# %%
sns.stripplot(data=df_ice)
# Out:
# <AxesSubplot:>

# %%
sns.boxenplot(data=df_ice)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=df_ice)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data=df_ice)
# Out:
# <AxesSubplot:>

# %%
sns.catplot(data=df_ice)

# %%
sns.countplot(data=df_ice)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
sns.scatterplot(data=df_ice)
# Out:
# <AxesSubplot:>

# %%
sns.relplot(data=df_ice)

# %%
sns.residplot(data=df_ice,x='Temperature', y='Revenue')
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Revenue'>

# %%
sns.swarmplot(data=df_ice)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 89.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 6.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:>

# %%
X=df_ice[['Temperature']]
y=df_ice['Revenue']

# %%
y
# Out:
# 0      534.799028
# 1      625.190122
# 2      660.632289
# 3      487.706960
# 4      316.240194
#           ...
# 495    524.746364
# 496    755.818399
# 497    306.090719
# 498    566.217304
# 499    655.660388
# Name: Revenue, Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X, y, random_state=0, test_size=0.2)

# %%
X_train.shape
# Out:
# (400, 1)

# %%
X_test.shape
# Out:
# (100, 1)

# %%
from sklearn.linear_model import LinearRegression
Regressor= LinearRegression(fit_intercept=True)

Regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Coefficient (m)', Regressor.coef_)
print('Linear Coefficient (b)', Regressor.intercept_)
# Out:
# Linear Coefficient (m) [21.5133908]
# Linear Coefficient (b) 43.73357869209292

# %%
y_pred = Regressor.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-af8e3a24d639> in <module>
#       1 from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# ----> 2 cm = confusion_matrix(y_test, y_pred)
#       3 sns.heatmap(cm, annot=True)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     294
#     295     """
# --> 296     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     297     if y_type not in ("binary", "multiclass"):
# ...

# %%
plt.scatter(X_train,y_train, color='grey')
plt.plot(X_train, Regressor.predict(X_train), color='r')
plt.xlabel('Revenue (Dollors)')
plt.ylabel('Temperature (Degc)')
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
plt.scatter(X_test, y_test, color='grey')
plt.plot(X_test, Regressor.predict(X_test), color='red')
plt.xlabel('Revenue')
plt.xlabel('Temperature')
plt.title('Revenue generated vs. Temperature Ice')
# Out:
# Text(0.5, 1.0, 'Revenue generated vs. Temperature Ice')

# %%
y_p = Regressor.predict(34)
y_p
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-320782c65992> in <module>
# ----> 1 y_p = Regressor.predict(34)
#       2 y_p
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     218         check_is_fitted(self)
#     219
# --> 220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     221         return safe_sparse_dot(X, self.coef_.T,
#     222                                dense_output=True) + self.intercept_
#
# ...

# %%
df_ice
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
X = df_ice[['Temperature']]
y = df_ice['Revenue']

# %%
X
# Out:
#      Temperature
# 0      24.566884
# 1      26.005191
# 2      27.790554
# 3      20.595335
# 4      11.503498
# ..           ...
# 495    22.274899
# 496    32.893092
# 497    12.588157
# 498    22.362402
# 499    28.957736
#
# [500 rows x 1 columns]

# %%
y
# Out:
# 0      534.799028
# 1      625.190122
# 2      660.632289
# 3      487.706960
# 4      316.240194
#           ...
# 495    524.746364
# 496    755.818399
# 497    306.090719
# 498    566.217304
# 499    655.660388
# Name: Revenue, Length: 500, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
Regressor = LinearRegression(fit_intercept=True)
Regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear coeficinet{b}' ,Regressor.coef_)
print('Liene',Regressor.intercept_)
# Out:
# Linear coeficinet{b} [21.5133908]
# Liene 43.73357869209292

# %%
Regressor.predict
